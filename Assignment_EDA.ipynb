# %% [markdown]
# ## Part 1: Understanding the Structure of the Dataset

# %%
import pandas as pd

# Load the Dataset
df = pd.read_csv('second_hand_cars.csv')

# %%
# Data Types
print(df.dtypes)
# Out:
# Company Name                object
# Car Name                    object
# Variant                     object
# Fuel Type                   object
# Tyre Condition              object
# Make Year                    int64
# Owner Type                  object
# Registration Number         object
# Mileage                      int64
# Price                        int64
# Transmission Type           object
# Body Color                  object
# Service Record              object
# Insurance                   object
# Registration Certificate    object
# Accessories                 object
# dtype: object

# %%
# Data Shape
print(df.shape)
# Out:
# (2500, 16)

# %%
# Feature Descriptions
print(df.describe())
# Out:
#          Make Year        Mileage          Price
# count  2500.000000    2500.000000    2500.000000
# mean   2019.521600  104777.792000  608120.897600
# std       2.894146   55544.487467  231056.126713
# min    2015.000000   10010.000000  200176.000000
# 25%    2017.000000   56313.000000  407791.000000
# 50%    2020.000000  104209.500000  612012.500000
# 75%    2022.000000  152149.250000  804567.000000
# max    2024.000000  199755.000000  999826.000000

# %% [markdown]
# # Part 2: Handling Missing Data and Outliers

# %% [markdown]
# Handling the missing data

# %%
# Identify Missing Values
print(df.isnull().sum())
# Out:
# Company Name                  0
# Car Name                      0
# Variant                     262
# Fuel Type                     0
# Tyre Condition                0
# Make Year                     0
# Owner Type                    0
# Registration Number           0
# Mileage                       0
# Price                         0
# Transmission Type             0
# Body Color                    0
# Service Record                0
# Insurance                     0
# Registration Certificate      0
# Accessories                 482
# dtype: int64

# %%
# Example: Fill missing values for 'Mileage' with the median
df['Mileage'].fillna(df['Mileage'].median(), inplace=True)

# %%
# Example: Drop rows with missing 'Price'
df.dropna(subset=['Price'], inplace=True)

# %% [markdown]
# ## Handling Outliers

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Identify Outliers using Box Plot
sns.boxplot(df['Price'])
plt.show()

# %%
# Example: Remove outliers based on IQR for 'Price'
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1
df = df[(df['Price'] >= (Q1 - 1.5 * IQR)) & (df['Price'] <= (Q3 + 1.5 * IQR))]

# %%
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# # Part 3: Exploratory Data Analysis Techniques

# %%
# Summary Statistics for Numerical Data
print(df.describe())
# Out:
#          Make Year        Mileage          Price
# count  2500.000000    2500.000000    2500.000000
# mean   2019.521600  104777.792000  608120.897600
# std       2.894146   55544.487467  231056.126713
# min    2015.000000   10010.000000  200176.000000
# 25%    2017.000000   56313.000000  407791.000000
# 50%    2020.000000  104209.500000  612012.500000
# 75%    2022.000000  152149.250000  804567.000000
# max    2024.000000  199755.000000  999826.000000

# %%
# Frequency Counts for Categorical Data
print(df['Fuel Type'].value_counts())
print(df['Owner Type'].value_counts())
# Out:
# Fuel Type
# CNG       840
# Diesel    833
# Petrol    827
# Name: count, dtype: int64
# Owner Type
# Third     855
# Second    833
# First     812
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
# Histograms
df['Mileage'].hist()
plt.title('Mileage histogram')
plt.xlabel('Mileage')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter Plot
plt.scatter(x=df['Mileage'], y=df['Price'])
plt.title('Scatter Plot')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.show()

# %%
# Bar Chart for Categorical Data
df['Fuel Type'].value_counts().plot(kind='bar')
plt.title('Fuel Type Bar Chart')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Part 4: Feature Engineering

# %% [markdown]
# Creating New Features

# %%
df.head()
# Out:
#    Company Name Car Name   Variant  Make Year Registration Number   Mileage  \
# 0             5    Cruze        EX       2018         84-436-5584 -0.936010
# 1             4   Seltos       RXE       2020         79-114-3166 -1.105025
# 2             4   Accord       RXE       2022         41-358-3344 -0.172127
# 3             6   Seltos  Highline       2024         92-708-1763 -0.619588
# 4             0     Kwid  Highline       2018         76-154-5485 -0.340800
#
#       Price Body Color              Service Record             Insurance  \
# 0  0.653591       Grey   Major Service at 50418 km  No Current Insurance
# 1 -0.446084     Maroon  Major Service at 131313 km  No Current Insurance
# 2  0.117749      Black           No Service Record  No Current Insurance
# 3 -0.540968     Maroon   Major Service at 98115 km    Valid Until [date]
# 4  0.453834     Silver  Major Service at 135665 km  No Current Insurance
#
#   Registration Certificate                          Accessories  \
# 0            Not Available  Music System, Sunroof, Alloy Wheels
# 1                Available                                  NaN
# 2                Available                                  NaN
# 3                Available           Music System, Alloy Wheels
# 4            Not Available                    GPS, Music System
#
#    Fuel Type_Diesel  Fuel Type_Petrol  \
# 0             False             False
# 1             False              True
# 2             False              True
# 3              True             False
# 4             False              True
#
#    Transmission Type_Automatic (Tiptronic)  Transmission Type_Manual  \
# 0                                    False                      True
# 1                                    False                     False
# 2                                     True                     False
# 3                                     True                     False
# 4                                     True                     False
#
#    Tyre Condition_New  Tyre Condition_Used  Owner Type_Second  \
# 0               False                False               True
# 1                True                False              False
# 2                True                False               True
# 3               False                 True              False
# 4               False                 True               True
#
#    Owner Type_Third
# 0             False
# 1              True
# 2             False
# 3              True
# 4             False

# %%
df['Make Year'] = pd.to_datetime(df['Make Year'])

# %%
# Extract Year from 'Make Year'
df['Year'] = df['Make Year'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 21 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Company Name                             2500 non-null   int64
#  1   Car Name                                 2500 non-null   object
#  2   Variant                                  2238 non-null   object
#  3   Make Year                                2500 non-null   datetime64[ns]
#  4   Registration Number                      2500 non-null   object
#  5   Mileage                                  2500 non-null   float64
#  6   Price                                    2500 non-null   float64
#  7   Body Color                               2500 non-null   object
#  8   Service Record                           2500 non-null   object
#  9   Insurance                                2500 non-null   object
#  10  Registration Certificate                 2500 non-null   object
#  11  Accessories                              2018 non-null   object
#  12  Fuel Type_Diesel                         2500 non-null   bool
#  13  Fuel Type_Petrol                         2500 non-null   bool
#  14  Transmission Type_Automatic (Tiptronic)  2500 non-null   bool
#  15  Transmission Type_Manual                 2500 non-null   bool
#  16  Tyre Condition_New                       2500 non-null   bool
#  17  Tyre Condition_Used                      2500 non-null   bool
#  18  Owner Type_Second                        2500 non-null   bool
#  19  Owner Type_Third                         2500 non-null   bool
#  20  Year                                     2500 non-null   int32
# dtypes: bool(8), datetime64[ns](1), float64(2), int32(1), int64(1), object(8)
# memory usage: 263.8+ KB

# %%
df = pd.read_csv('second_hand_cars.csv')

# %%
# Convert Categorical Variables into Dummy Variables
df = pd.get_dummies(data=df, columns=['Fuel Type', 'Transmission Type', 'Tyre Condition', 'Owner Type'], drop_first=True)

# %% [markdown]
# ## Transforming Existing Features

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Normalize Numerical Features
scaler = StandardScaler()
df[['Mileage', 'Price']] = scaler.fit_transform(df[['Mileage', 'Price']])

# %%
# Label Encoding
label_encoder = LabelEncoder()
df['Company Name'] = label_encoder.fit_transform(df['Company Name'])

# %%
df.head()
# Out:
#    Company Name Car Name   Variant  Make Year Registration Number   Mileage  \
# 0             5    Cruze        EX       2018         84-436-5584 -0.936010
# 1             4   Seltos       RXE       2020         79-114-3166 -1.105025
# 2             4   Accord       RXE       2022         41-358-3344 -0.172127
# 3             6   Seltos  Highline       2024         92-708-1763 -0.619588
# 4             0     Kwid  Highline       2018         76-154-5485 -0.340800
#
#       Price Body Color              Service Record             Insurance  \
# 0  0.653591       Grey   Major Service at 50418 km  No Current Insurance
# 1 -0.446084     Maroon  Major Service at 131313 km  No Current Insurance
# 2  0.117749      Black           No Service Record  No Current Insurance
# 3 -0.540968     Maroon   Major Service at 98115 km    Valid Until [date]
# 4  0.453834     Silver  Major Service at 135665 km  No Current Insurance
#
#   Registration Certificate                          Accessories  \
# 0            Not Available  Music System, Sunroof, Alloy Wheels
# 1                Available                                  NaN
# 2                Available                                  NaN
# 3                Available           Music System, Alloy Wheels
# 4            Not Available                    GPS, Music System
#
#    Fuel Type_Diesel  Fuel Type_Petrol  \
# 0             False             False
# 1             False              True
# 2             False              True
# 3              True             False
# 4             False              True
#
#    Transmission Type_Automatic (Tiptronic)  Transmission Type_Manual  \
# 0                                    False                      True
# 1                                    False                     False
# 2                                     True                     False
# 3                                     True                     False
# 4                                     True                     False
#
#    Tyre Condition_New  Tyre Condition_Used  Owner Type_Second  \
# 0               False                False               True
# 1                True                False              False
# 2                True                False               True
# 3               False                 True              False
# 4               False                 True               True
#
#    Owner Type_Third
# 0             False
# 1              True
# 2             False
# 3              True
# 4             False

# %% [markdown]
# ## Feature Selection

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# %%
X = df.drop('Price', axis=1, errors='ignore')  # Exclude 'Price' from features
y = df['Price'] if 'Price' in df.columns else None

# %%
if y is not None:

    X_encoded = pd.get_dummies(X, drop_first=True)
    

    if X_encoded.isnull().sum().sum() == 0:
        # Correlation Matrix
        corr_matrix = X_encoded.corr()
        sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
        plt.title('Correlation Matrix')
        plt.show()

        # Feature Importance using RandomForest
        model = RandomForestRegressor()
        model.fit(X_encoded, y)
        importances = model.feature_importances_
        feature_names = X_encoded.columns
        feature_importance = pd.Series(importances, index=feature_names).sort_values(ascending=False)
        print(feature_importance)
    else:
        print("There are missing values in the feature matrix.")
else:
    print("Price column is not present in the DataFrame.")
# Out:
# Mileage                                      1.361063e-01
# Company Name                                 5.429335e-02
# Make Year                                    5.285250e-02
# Insurance_Valid Until [date]                 1.264730e-02
# Registration Certificate_Not Available       1.262270e-02
#                                                  ...
# Service Record_Major Service at 146053 km    1.389516e-07
# Service Record_Major Service at 62625 km     1.253082e-07
# Registration Number_68-651-9371              1.187758e-07
# Service Record_Major Service at 139767 km    1.173278e-07
# Registration Number_24-965-4772              1.120371e-07
# Length: 3586, dtype: float64
